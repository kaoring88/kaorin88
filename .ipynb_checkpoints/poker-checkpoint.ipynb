# %%
import random

H2=["heart",2]
S2=["spead",2]
D2=["daiya",2]
C2=["clover",2]

H3=["heart",3]
S3=["spead",3]
D3=["daiya",3]
C3=["clover",3]

H4=["heart",4]
S4=["spead",4]
D4=["daiya",4]
C4=["clover",4]

H5=["heart",5]
S5=["spead",5]
D5=["daiya",5]
C5=["clover",5]

H6=["heart",6]
S6=["spead",6]
D6=["daiya",6]
C6=["clover",6]

H7=["heart",7]
S7=["spead",7]
D7=["daiya",7]
C7=["clover",7]

H8=["heart",8]
S8=["spead",8]
D8=["daiya",8]
C8=["clover",8]

H9=["heart",9]
S9=["spead",9]
D9=["daiya",9]
C9=["clover",9]

H10=["heart",10]
S10=["spead",10]
D10=["daiya",10]
C10=["clover",10]

H11=["heart",11]
S11=["spead",11]
D11=["daiya",11]
C11=["clover",11]

H12=["heart",12]
S12=["spead",12]
D12=["daiya",12]
C12=["clover",12]

H13=["heart",13]
S13=["spead",13]
D13=["daiya",13]
C13=["clover",13]

HA14=["heart",14]
SA14=["spead",14]
DA14=["daiya",14]
CA14=["clover",14]

x=[H2,S2,D2,C2,H3,S3,D3,C3,H4,S4,D4,C4,H5,S5,D5,C5,H6,S6,D6,C6,H7,S7,D7,C7,H8,S8,D8,C8,
   H9,S9,D9,C9,H10,S10,D10,C10,H11,S11,D11,C11,H12,S12,D12,C12,H13,S13,D13,C13,
   HA14,SA14,DA14,CA14]
y=random.sample(x, len(x))
My=[]
Cpu=[]

for i in range(5):
    m=y.pop()
    c=y.pop()
    My.append(m)
    Cpu.append(c)
    
syuruiM=[]
suujiM=[]
syuruiC=[]
suujiC=[]

for m in My:
    syuruiM.append(m[0])
    suujiM.append(m[1])
for c in Cpu:
    syuruiC.append(c[0])
    suujiC.append(c[1])
    
    
#ここにカード入替を入れる



#先にフォアカードかフルハウスか判断
fourcardM=0
for sm1 in suujiM:
    for sm2 in suujiM:
        if sm1==sm2:
            fourcardM+=1
        else:
            pass
fullhouseM=0
for sm3 in suujiM:
    for sm4 in suujiM:
        if sm3==sm4:
            fullhouseM+=1
        else:
            pass
    
if syuruiM[0]==syuruiM[1] and syuruiM[0]==syuruiM[2] and syuruiM[0]==syuruiM[3] and syuruiM[0]==syuruiM[4]:#種類が同じか
    if suujiM[0]==10 and suujiM[1]==11 and suujiM[2]==12 and suujiM[3]==13 and suujiM[4]==14:#ロイヤルか
        print("ロイヤルストレートフラッシュ！")
    elif suujiM[0]+1==suujiM[1] and suujiM[0]+2==suujiM[2] and suujiM[0]+3==suujiM[3] and suujiM[0]+4==suujiM[4]:#ストレートか
        print("ストレートフラッシュ！")
    elif fourcardM==17:
        print("フォアカード！")
    elif fullhouseM==13:
        print("フルハウス！")
    else:
        print("フラッシュ！")

#スリーカード、ツーペア、ワンペア
threecardM=0
for sm5 in suujiM:
    for sm6 in suujiM:
        if sm5==sm6:
            threecardM+=1
        else:
            pass
        
twopairM=0
for sm7 in suujiM:
    for sm8 in suujiM:
        if sm7==sm8:
            twopairM+=1
        else:
            pass

onepairM=0
for sm9 in suujiM:
    for sm10 in suujiM:
        if sm9==sm10:
            onepairM+=1
        else:
            pass
        
if fourcardM==17:#フォアカード
    print("フォアカード！")
elif fullhouseM==13:#フルハウス
    print("フルハウス！")
elif suujiM[0]+1==suujiM[1] and suujiM[0]+2==suujiM[2] and suujiM[0]+3==suujiM[3] and suujiM[0]+4==suujiM[4]:
    print("ストレート！")
elif threecardM==11:
    print("スリーカード！")
elif twopairM==9:
    print("ツーペア！")
elif onepairM==7:
    print("ワンペア！")
else:
    print("ノーペア！")
print(My[0])
# Out:
# ワンペア！
# ['spead', 4]

# %%
import random
a=[1,2,3]
random.sample(a, len(a))
# Out:
# [2, 3, 1]

# %%
if a==True:
    print(a)
else:
    print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-626472a94bad> in <module>
# ----> 1 if a==True:
#       2     print(a)
#       3 else:
#       4     print(b)
#
# NameError: name 'a' is not defined

# %%
#シャッフルします
y=random.sample(x, len(x))
My=[]#自分の手札五枚


for i in range(5):
    m=y.pop()
    My.append(m)
#お互い数字とカードの種類に分けます    
syuruiM=[]
suujiM=[]

for m in My:
    syuruiM.append(m[0])
    suujiM.append(m[1])

fourcardM=0
for sm1 in suujiM:
    for sm2 in suujiM:
        if sm1==sm2:
            fourcardM+=1
        else:
            pass
fullhouseM=0
for sm3 in suujiM:
    for sm4 in suujiM:
        if sm3==sm4:
            fullhouseM+=1
        else:
            pass

threecardM=0
for sm5 in suujiM:
    for sm6 in suujiM:
        if sm5==sm6:
            threecardM+=1
        else:
            pass
        
twopairM=0
for sm7 in suujiM:
    for sm8 in suujiM:
        if sm7==sm8:
            twopairM+=1
        else:
            pass

onepairM=0
for sm9 in suujiM:
    for sm10 in suujiM:
        if sm9==sm10:
            onepairM+=1
        else:
            pass
# Out:
# int

# %%
,fourcardM=fourcardM,fullhouseM=fullhouseM,threecardM=threecardM,twopairM=twopairM,onepairM=onepairM
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c426303f4614> in <module>
# ----> 1 fourcardM=fourcardM,fullhouseM=fullhouseM,threecardM=threecardM,twopairM=twopairM,onepairM=onepairM("")
#
# NameError: name 'onepairM' is not defined

# %%
    y=random.sample(x, len(x))
    My=[]#自分の手札五枚
    for i in range(5):
        m=y.pop()
        My.append(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-765896050f9d> in <module>
# ----> 1 y=random.sample(x, len(x))
#       2 My=[]#自分の手札五枚
#       3 for i in range(5):
#       4     m=y.pop()
#       5     My.append(m)
#
# NameError: name 'random' is not defined

# %%
a={"aa":1}
print(a["aa"])
# Out:
# 1

# %%
a=["H2","H3"]
a.pop()
print(a)
# Out:
# ['H2']

# %%
strdict={"H2":H2,"S2":S2,"D2":D2,"C2":C2,"H3":H3,"S3":S3,"D3":D3,"C3":C3,"H4":H4,"S4":S4,"D4":D4,"C4":C4,"H5":H5,"S5":S5,"D5":D5,"C5":C5,"H6":H6,"S6":S6,"D6":D6,"C6":C6,"H7":H7,"S7":S7,"D7":D7,"C7":C7,"H8":H8,"S8":S8,"D8":D8,"C8":C8,
   "H9":H9,"S9":S9,"D9":D9,"C9":C9,"H10":H10,"S10":S10,"D10":D10,"C10":C10,"H11":H11,"S11":S11,"D11":D11,"C11":C11,"H12":H12,"S12":S12,"D12":D12,"C12":C12,"H13":H13,"S13":S13,"D13":D13,"C13":C13,
   "HA14":HA14,"SA14":SA14,"DA14":DA14,"CA14":CA14}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-19201c4c4355> in <module>
# ----> 1 strdict={"H2":H2,"S2":S2,"D2":D2,"C2":C2,"H3":H3,"S3":S3,"D3":D3,"C3":C3,"H4":H4,"S4":S4,"D4":D4,"C4":C4,"H5":H5,"S5":S5,"D5":D5,"C5":C5,"H6":H6,"S6":S6,"D6":D6,"C6":C6,"H7":H7,"S7":S7,"D7":D7,"C7":C7,"H8":H8,"S8":S8,"D8":D8,"C8":C8,
#       2    "H9":H9,"S9":S9,"D9":D9,"C9":C9,"H10":H10,"S10":S10,"D10":D10,"C10":C10,"H11":H11,"S11":S11,"D11":D11,"C11":C11,"H12":H12,"S12":S12,"D12":D12,"C12":C12,"H13":H13,"S13":S13,"D13":D13,"C13":C13,
#       3    "HA14":HA14,"SA14":SA14,"DA14":DA14,"CA14":CA14}
#
# NameError: name 'H2' is not defined

# %%
b=[2,5,4,3,1]
print(sorted(b))
# Out:
# [1, 2, 3, 4, 5]

# %%
import openpyxl
    wb=openpyxl.load_workbook("card.xlsx")
    ws=wb["card"]
    wc=ws.cell(row=1, column=1)
wc
# Out:
#   File "<ipython-input-3-f9744e86583c>", line 2
#     wb=openpyxl.load_workbook("card.xlsx")
#     ^
# IndentationError: unexpected indent

# %%
from argparse import MetavarTypeHelpFormatter
from re import A
from flask import Flask, render_template, request
import random
import openpyxl


app=Flask(__name__)

H2=["heart",2]
S2=["spead",2]
D2=["daiya",2]
C2=["clover",2]

H3=["heart",3]
S3=["spead",3]
D3=["daiya",3]
C3=["clover",3]

H4=["heart",4]
S4=["spead",4]
D4=["daiya",4]
C4=["clover",4]

H5=["heart",5]
S5=["spead",5]
D5=["daiya",5]
C5=["clover",5]

H6=["heart",6]
S6=["spead",6]
D6=["daiya",6]
C6=["clover",6]

H7=["heart",7]
S7=["spead",7]
D7=["daiya",7]
C7=["clover",7]

H8=["heart",8]
S8=["spead",8]
D8=["daiya",8]
C8=["clover",8]

H9=["heart",9]
S9=["spead",9]
D9=["daiya",9]
C9=["clover",9]

H10=["heart",10]
S10=["spead",10]
D10=["daiya",10]
C10=["clover",10]

H11=["heart",11]
S11=["spead",11]
D11=["daiya",11]
C11=["clover",11]

H12=["heart",12]
S12=["spead",12]
D12=["daiya",12]
C12=["clover",12]

H13=["heart",13]
S13=["spead",13]
D13=["daiya",13]
C13=["clover",13]

HA14=["heart",14]
SA14=["spead",14]
DA14=["daiya",14]
CA14=["clover",14]

x=[H2,S2,D2,C2,H3,S3,D3,C3,H4,S4,D4,C4,H5,S5,D5,C5,H6,S6,D6,C6,H7,S7,D7,C7,H8,S8,D8,C8,
   H9,S9,D9,C9,H10,S10,D10,C10,H11,S11,D11,C11,H12,S12,D12,C12,H13,S13,D13,C13,
   HA14,SA14,DA14,CA14]
strdict={"H2":H2,"S2":S2,"D2":D2,"C2":C2,"H3":H3,"S3":S3,"D3":D3,"C3":C3,"H4":H4,"S4":S4,"D4":D4,"C4":C4,"H5":H5,"S5":S5,"D5":D5,"C5":C5,"H6":H6,"S6":S6,"D6":D6,"C6":C6,"H7":H7,"S7":S7,"D7":D7,"C7":C7,"H8":H8,"S8":S8,"D8":D8,"C8":C8,
   "H9":H9,"S9":S9,"D9":D9,"C9":C9,"H10":H10,"S10":S10,"D10":D10,"C10":C10,"H11":H11,"S11":S11,"D11":D11,"C11":C11,"H12":H12,"S12":S12,"D12":D12,"C12":C12,"H13":H13,"S13":S13,"D13":D13,"C13":C13,
   "HA14":HA14,"SA14":SA14,"DA14":DA14,"CA14":CA14}
y=random.sample(x, len(x))

My=[1,2,3,4,5]
score=0
@app.route("/")
def start():
    My00=None
    My11=None
    My22=None
    My33=None
    My44=None
    for i in range(5):
        m=y.pop()
        My[i]=m
    book=openpyxl.load_workbook("card.xlsx")
    sheet=book["card"]
    sheet["A1"]=My00
    sheet["B1"]=My11
    sheet["C1"]=My22
    sheet["D1"]=My33
    sheet["E1"]=My44
    book.save("card.xlsx")
    a=len(y)
    return render_template("start.html",My00=My00,My11=My11,My22=My22,My33=My33,My44=My44,a=a,y=y,m=m,My=My,My0=My[0],My1=My[1],My2=My[2],My3=My[3],My4=My[4],H2=H2,S2=S2,D2=D2,C2=C2,H3=H3,S3=S3,D3=D3,C3=C3,H4=H4,S4=S4,D4=D4,C4=C4,H5=H5,S5=S5,D5=D5,C5=C5,H6=H6,S6=S6,D6=D6,C6=C6,H7=H7,S7=S7,D7=D7,C7=C7,H8=H8,S8=S8,D8=D8,C8=C8,H9=H9,S9=S9,D9=D9,C9=C9,H10=H10,S10=S10,D10=D10,C10=C10,H11=H11,S11=S11,D11=D11,C11=C11,H12=H12,S12=S12,D12=D12,C12=C12,H13=H13,S13=S13,D13=D13,C13=C13,HA14=HA14,SA14=SA14,DA14=DA14,CA14=CA14)

@app.route("/start1", methods=["POST"])
def change():
    My00=None
    My11=None
    My22=None
    My33=None
    My44=None
    My00=request.form.get("My00")
    My11=request.form.get("My11")
    My22=request.form.get("My22")
    My33=request.form.get("My33")
    My44=request.form.get("My44")
    book=openpyxl.load_workbook("card.xlsx")
    sheet=book["card"]
    if My00!=None:
        sheet["A1"]=My00
    if My11!=None:
        sheet["B1"]=My11
    if My22!=None:
        sheet["C1"]=My22
    if My33!=None:
        sheet["D1"]=My33
    if My44!=None:    
        sheet["E1"]=My44
    book.save("card.xlsx")
    a=len(y)
    return render_template("start1.html",a=a,y=y,My00=My00,My11=My11,My22=My22,My33=My33,My44=My44,My0=My[0],My1=My[1],My2=My[2],My3=My[3],My4=My[4],H2=H2,S2=S2,D2=D2,C2=C2,H3=H3,S3=S3,D3=D3,C3=C3,H4=H4,S4=S4,D4=D4,C4=C4,H5=H5,S5=S5,D5=D5,C5=C5,H6=H6,S6=S6,D6=D6,C6=C6,H7=H7,S7=S7,D7=D7,C7=C7,H8=H8,S8=S8,D8=D8,C8=C8,H9=H9,S9=S9,D9=D9,C9=C9,H10=H10,S10=S10,D10=D10,C10=C10,H11=H11,S11=S11,D11=D11,C11=C11,H12=H12,S12=S12,D12=D12,C12=C12,H13=H13,S13=S13,D13=D13,C13=C13,HA14=HA14,SA14=SA14,DA14=DA14,CA14=CA14)

@app.route("/result", methods=["POST"])
def result():
    wb=openpyxl.load_workbook("card.xlsx")
    ws=wb["card"]
    cellA=ws["A1"]
    cellB=ws["B1"]
    cellC=ws["C1"]
    cellD=ws["D1"]
    cellE=ws["E1"]
    if cellA.value!=None:
        My[0]=y.pop()
    if cellB.value!=None:
        My[1]=y.pop()
    if cellC.value!=None:
        My[2]=y.pop()
    if cellD.value!=None:
        My[3]=y.pop()
    if cellE.value!=None:
        My[4]=y.pop()        
    result=request.form.get("result")
    syuruiM=[]
    suujiM=[]
    fourcardM=0
    fullhouseM=0
    threecardM=0
    twopairM=0
    onepairM=0
    nopairM=0
    for m in My:
        syuruiM.append(m[0])
        suujiM.append(m[1])
    for sm1 in suujiM:
        for sm2 in suujiM:
            if sm1==sm2:
                fourcardM+=1
            else:
                pass
    for sm3 in suujiM:
        for sm4 in suujiM:
            if sm3==sm4:
                fullhouseM+=1
            else:
                pass
    for sm5 in suujiM:
        for sm6 in suujiM:
            if sm5==sm6:
                threecardM+=1
            else:
                pass
    for sm7 in suujiM:
        for sm8 in suujiM:
            if sm7==sm8:
                twopairM+=1
            else:
                pass
    for sm9 in suujiM:
        for sm10 in suujiM:
            if sm9==sm10:
                onepairM+=1
            else:
                pass
    for sm11 in suujiM:
        for sm12 in suujiM:
            if sm11==sm12:
                nopairM+=1
            else:
                pass
    suujiMS=sorted(suujiM)
    a=len(y)
    return render_template("result.html",score=score,y=y,a=a,suujiMS=suujiMS,result=result,My=My,fourcardM=fourcardM,fullhouseM=fullhouseM,threecardM=threecardM,twopairM=twopairM,onepairM=onepairM,nopairM=nopairM,syuruiM=syuruiM,suujiM=suujiM,My0=My[0],My1=My[1],My2=My[2],My3=My[3],My4=My[4],H2=H2,S2=S2,D2=D2,C2=C2,H3=H3,S3=S3,D3=D3,C3=C3,H4=H4,S4=S4,D4=D4,C4=C4,H5=H5,S5=S5,D5=D5,C5=C5,H6=H6,S6=S6,D6=D6,C6=C6,H7=H7,S7=S7,D7=D7,C7=C7,H8=H8,S8=S8,D8=D8,C8=C8,H9=H9,S9=S9,D9=D9,C9=C9,H10=H10,S10=S10,D10=D10,C10=C10,H11=H11,S11=S11,D11=D11,C11=C11,H12=H12,S12=S12,D12=D12,C12=C12,H13=H13,S13=S13,D13=D13,C13=C13,HA14=HA14,SA14=SA14,DA14=DA14,CA14=CA14)


if __name__=="__main__":
    app.run(host="localhost", debug=True)
